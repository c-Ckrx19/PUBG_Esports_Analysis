# %% [markdown]
# ## Exploratory analysis

# %%
import pandas as pd

# %%
df_a = pd.read_csv("group_stage_stats.csv")
df_a
# Out:
#           Player    PTS  Number of Matches  Kills  Assists  KDA   KD  KAS  \
# 0     DAY_TiGGER  93.07                 12     25       14  3.5  2.3  0.8
# 1      DAY_Flash  81.19                 12     23       10  3.0  2.1  0.8
# 2        TWIS_Lu  80.18                 12     20       10  2.5  1.7  0.8
# 3     TE_Clories  92.67                 12     23        6  2.6  2.1  0.8
# 4   BB_Bestoloch  81.66                 12     19       11  3.0  1.9  0.8
# ..           ...    ...                ...    ...      ...  ...  ...  ...
# 91      VP_Beami  16.96                 12      2        6  0.7  0.2  0.3
# 92    VP_Lukarux  18.22                 12      4        1  0.4  0.3  0.3
# 93  PeRo_Nannnnn  19.82                 12      4        1  0.5  0.4  0.3
# 94   BST_SzylzEN   9.76                 12      2        2  0.3  0.2  0.3
# 95      VP_ibiza  11.89                 12      3        1  0.3  0.3  0.3
#
#     Knocks  Kills/Knocks  ...  Flashes Thrown  Swimming Distance (km)  \
# 0       22           1.1  ...               6                     0.0
# 1       20           1.1  ...               6                     0.0
# 2       21           1.0  ...               9                     0.1
# 3       21           1.1  ...               9                     0.0
# 4       13           1.5  ...               0                     0.0
# ..     ...           ...  ...             ...                     ...
# 91       6           0.3  ...               0                     0.0
# 92       4           1.0  ...               0                     0.0
# 93       2           2.0  ...               2                     0.0
# 94       4           0.5  ...               3                     0.0
# 95       1           3.0  ...               9                     0.0
#
#     Walk Distance (km)  Ride Distance (km)  Time Survived  Avg Time Survived  \
# 0                 15.5                34.4          16371               1364
# 1                 15.3                31.7          15618               1301
# 2                 15.4                39.7          18371               1530
# 3                 12.7                35.0          16462               1371
# 4                 13.6                40.1          17138               1428
# ..                 ...                 ...            ...                ...
# 91                 9.4                67.7          13480               1123
# 92                 9.8                67.7          12732               1061
# 93                11.2                38.5          13396               1116
# 94                12.7                43.7          15186               1265
# 95                11.6                77.5          14034               1169
#
#     Heals  Health Recovered  Boosts  Vehicle Destroys
# 0      28            1640.4      58                 4
# 1      42            2287.7      32                 2
# 2      50            2691.1      42                 0
# 3      31            1993.2      49                 5
# 4      38            2530.6      39                 3
# ..    ...               ...     ...               ...
# 91     77            3969.3      29                 0
# 92     35            1668.6      44                 2
# 93     16             827.7      26                 0
# 94      9             736.1      49                 1
# 95     98            4089.6      48                 0
#
# [96 rows x 54 columns]

# %% [markdown]
# Correlation between KDA and KD

# %%
df_a["KDA"].corr(df_a["KD"]).item() * 100
# Out:
# 92.76549930604604

# %%
df_a["KDA"].corr(df_a["PTS"]).item() * 100
# Out:
# 92.43097925715648

# %% [markdown]
# ## Model

# %% [markdown]
# Feature selection

# %%
# 选择特征列 (X) 和目标列 (y)
X = df_a[['KDA', 'Avg Time Survived']]  # 选择多列作为特征
y = df_a['PTS']                  # 选择单列作为目标

print("特征数据 (X):\n", X)
print("目标数据 (y):\n", y)
# Out:
# 特征数据 (X):
#      KDA  Avg Time Survived
# 0   3.5               1364
# 1   3.0               1301
# 2   2.5               1530
# 3   2.6               1371
# 4   3.0               1428
# ..  ...                ...
# 91  0.7               1123
# 92  0.4               1061
# 93  0.5               1116
# 94  0.3               1265
# 95  0.3               1169
#
# [96 rows x 2 columns]
# 目标数据 (y):
#  0     93.07
# 1     81.19
# 2     80.18
# 3     92.67
# 4     81.66
#       ...
# 91    16.96
# 92    18.22
# 93    19.82
# 94     9.76
# 95    11.89
# Name: PTS, Length: 96, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# Modeling and evaluation

# %%
from sklearn.linear_model import LinearRegression

# 初始化模型
model = LinearRegression()

# 训练模型
model.fit(X_train, y_train)  # 如果未划分训练集，直接用 model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("回归系数:", model.coef_)    # 对应 feature1 和 feature3 的权重
print("截距:", model.intercept_)  # 模型偏置项

# 预测测试集
y_pred = model.predict(X_test)
print("预测值:", y_pred)
# Out:
# 回归系数: [2.4052196e+01 2.3760562e-02]
# 截距: -20.880228879561344
# 预测值: [27.00381081 31.06686692 39.42303269 16.39254086 43.20636489 30.34324438
#  35.4204526  43.90082402 95.71186368 60.48894993 28.14431779 47.72627451
#  60.94580344 85.20644166 40.00949469 50.95771094 59.49100632 58.58810496
#  27.85919104 21.83696318 45.51654224 38.03411442 74.94943092 31.39951478
#  24.1125743  68.99848474 42.49895086 53.32621509 35.59758221]

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("均方误差 (MSE):", mse)
print("R² 分数:", r2)
n = len(y)
k = X.shape[1]
adjusted_r_squared = 1 - (1 - r2) * (n - 1) / (n - k - 1)
print(adjusted_r_squared)
# Out:
# 均方误差 (MSE): 52.444002684494016
# R² 分数: 0.8800997861971492
# 0.8775212869755825

# %% [markdown]
# ### Prediction

# %%
player_prediction_player = df_a['Player'].to_numpy()
player_prediction_player
# Out:
# array(['DAY_TiGGER', 'DAY_Flash', 'TWIS_Lu', 'TE_Clories', 'BB_Bestoloch',
#        'DAY_Belmoth', 'DAY_Thanad0l', 'TKL_Cold119', 'TKL_Spaceman',
#        'FLC_TGLTN', 'FLC_Kickstart', 'TE_TanVuu', 'BGP_2heart',
#        'BB_Molodoct', 'TWIS_xmpl', 'FOR_KISS', 'PeRo_Aixleft',
#        'FLC_Shrimzy', 'BB_f1lfirst', 'BB_ADOUZ1E', 'GEN_BeaN', 'NH_16KK',
#        'BST_Dr4FTk1NG', 'TWIS_BatulinS', 'DNF_DIEL', 'DNF_Salute',
#        'TWIS_Perfect1ks', 'TKL_Donzz', 'GK_spyrro', 'NH_Dec12th',
#        'NH_ZiLong1', 'T1_Heather', 'FUR_guizeraa', 'EA_Xizzy', '17_Xbei',
#        'TKL_SuZe', 'BST_v1n1zxz', 'DNF_Heaven', '17_77owo', 'TE_Delwyn',
#        'NH_Inuyasha', 'BGP_Parkpro', 'EA_Nourinz', 'T5_Flukky',
#        'FLC_hwinn', 'VP_NIXZYEE', 'NAVI_Feyerist', '4AM_ATongMuu',
#        'FOR_Olympus', 'PeRo_MMing', 'BGP_AKaN', 'FOR_Baren', 'FOR_Scappy',
#        '17_Lilghost', '17_xwudd', 'NAVI_Hakatory', 'NAVI_SoseD',
#        'NAVI_staed', 'T1_EEND', 'GEN_Tosi', 'T1_Type', '4AM_Longz',
#        'GK_pwddddddddd', 'T5_RangerX', 'ROC_bielmtcalmo', 'EA_Jacob',
#        'FUR_possa', 'T5_RossitedJR', '4AM_HSmm', 'TE_DuCkHjeUz',
#        'FUR_Haven', 'DN_Barpo', 'FUR_zkrakeN', 'EA_Lericz', 'GEN_Orca',
#        'DN_Daeyeon', 'BST_M1ME', 'GK_QWZYYY', 'DNF_Gyumin',
#        'T5_Pathompong', 'T1_Rain1ng', 'BGP_Seongjang', 'GK_HIRUZEN',
#        'GEN_Americano', 'ROC_soldzzzz', 'ROC_sxntastico', 'DN_Hela',
#        'DN_wonderful', 'PeRo_Cui71', 'ROC_rbN777', '4AM_Godv', 'VP_Beami',
#        'VP_Lukarux', 'PeRo_Nannnnn', 'BST_SzylzEN', 'VP_ibiza'],
#       dtype=object)

# %%
player_prediction_pts_X = df_a[['KDA', 'Avg Time Survived']]
player_prediction_pts = model.predict(player_prediction_pts_X)
player_prediction_pts
# Out:
# array([95.71186368, 82.18885028, 75.60392098, 74.23121122, 85.20644166,
#        83.30559669, 69.94350439, 65.95172997, 79.04165042, 68.99848474,
#        60.48894993, 53.32621509, 59.49100632, 78.70900255, 46.8600886 ,
#        74.94943092, 67.686251  , 63.09505969, 60.94580344, 59.49100632,
#        38.8527792 , 51.94269965, 58.58810496, 56.84277826, 60.87452175,
#        56.47341495, 50.95771094, 70.4003579 , 38.3538074 , 44.03258172,
#        47.72627451, 40.00949469, 53.13613059, 43.20636489, 42.88992553,
#        47.15602102, 51.96646022, 38.58601018, 49.78589135, 42.49895086,
#        45.51654224, 47.7554379 , 43.90082402, 45.36857603, 46.94217596,
#        35.59758221, 33.82094289, 35.37833431, 52.5658771 , 39.13250311,
#        41.98917339, 52.32827148, 47.04262104, 27.85919104, 33.02603867,
#        24.38474615, 28.86253749, 47.38067175, 28.33440228, 36.70892579,
#        36.64304694, 42.23758468, 29.23730364, 47.29858439, 28.14431779,
#        37.87859616, 40.89618754, 38.03411442, 31.39951478, 35.4204526 ,
#        31.56583872, 22.1037322 , 31.42327535, 39.42303269, 23.07251241,
#        22.21713218, 38.93701578, 31.06686692, 26.86879949, 30.34324438,
#        27.00381081, 35.6105371 , 34.96900192, 27.30189245, 24.33182219,
#        21.83696318, 25.71533763, 20.3584055 , 24.1125743 , 19.80650974,
#        26.28018828, 22.63941946, 13.95060581, 17.66265632, 16.39254086,
#        14.11152691])

# %%
players_data_pred = pd.DataFrame({'Player': player_prediction_player, 'PTS_pred': player_prediction_pts})
pd.set_option('display.max_rows', None)
players_data_pred.sort_values('PTS_pred', ascending=False)
# Out:
#              Player   PTS_pred
# 0        DAY_TiGGER  95.711864
# 4      BB_Bestoloch  85.206442
# 5       DAY_Belmoth  83.305597
# 1         DAY_Flash  82.188850
# 8      TKL_Spaceman  79.041650
# 13      BB_Molodoct  78.709003
# 2           TWIS_Lu  75.603921
# 15         FOR_KISS  74.949431
# 3        TE_Clories  74.231211
# 27        TKL_Donzz  70.400358
# 6      DAY_Thanad0l  69.943504
# 9         FLC_TGLTN  68.998485
# 16     PeRo_Aixleft  67.686251
# 7       TKL_Cold119  65.951730
# 17      FLC_Shrimzy  63.095060
# 18      BB_f1lfirst  60.945803
# 24         DNF_DIEL  60.874522
# 10    FLC_Kickstart  60.488950
# 12       BGP_2heart  59.491006
# 19       BB_ADOUZ1E  59.491006
# 22    BST_Dr4FTk1NG  58.588105
# 23    TWIS_BatulinS  56.842778
# 25       DNF_Salute  56.473415
# 11        TE_TanVuu  53.326215
# 32     FUR_guizeraa  53.136131
# 48      FOR_Olympus  52.565877
# 51        FOR_Baren  52.328271
# 36      BST_v1n1zxz  51.966460
# 21          NH_16KK  51.942700
# 26  TWIS_Perfect1ks  50.957711
# 38         17_77owo  49.785891
# 41      BGP_Parkpro  47.755438
# 30       NH_ZiLong1  47.726275
# 57       NAVI_staed  47.380672
# 63       T5_RangerX  47.298584
# 35         TKL_SuZe  47.156021
# 52       FOR_Scappy  47.042621
# 44        FLC_hwinn  46.942176
# 14        TWIS_xmpl  46.860089
# 40      NH_Inuyasha  45.516542
# 43        T5_Flukky  45.368576
# 29       NH_Dec12th  44.032582
# 42       EA_Nourinz  43.900824
# 33         EA_Xizzy  43.206365
# 34          17_Xbei  42.889926
# 39        TE_Delwyn  42.498951
# 61        4AM_Longz  42.237585
# 50         BGP_AKaN  41.989173
# 66        FUR_possa  40.896188
# 31       T1_Heather  40.009495
# 73        EA_Lericz  39.423033
# 49       PeRo_MMing  39.132503
# 76         BST_M1ME  38.937016
# 20         GEN_BeaN  38.852779
# 37       DNF_Heaven  38.586010
# 28        GK_spyrro  38.353807
# 67    T5_RossitedJR  38.034114
# 65         EA_Jacob  37.878596
# 59         GEN_Tosi  36.708926
# 60          T1_Type  36.643047
# 81    BGP_Seongjang  35.610537
# 45       VP_NIXZYEE  35.597582
# 69     TE_DuCkHjeUz  35.420453
# 47     4AM_ATongMuu  35.378334
# 82       GK_HIRUZEN  34.969002
# 46    NAVI_Feyerist  33.820943
# 54         17_xwudd  33.026039
# 70        FUR_Haven  31.565839
# 72      FUR_zkrakeN  31.423275
# 68         4AM_HSmm  31.399515
# 77        GK_QWZYYY  31.066867
# 79    T5_Pathompong  30.343244
# 62   GK_pwddddddddd  29.237304
# 56       NAVI_SoseD  28.862537
# 58          T1_EEND  28.334402
# 64  ROC_bielmtcalmo  28.144318
# 53      17_Lilghost  27.859191
# 83    GEN_Americano  27.301892
# 80       T1_Rain1ng  27.003811
# 78       DNF_Gyumin  26.868799
# 90         4AM_Godv  26.280188
# 86          DN_Hela  25.715338
# 55    NAVI_Hakatory  24.384746
# 84     ROC_soldzzzz  24.331822
# 88       PeRo_Cui71  24.112574
# 74         GEN_Orca  23.072512
# 91         VP_Beami  22.639419
# 75       DN_Daeyeon  22.217132
# 71         DN_Barpo  22.103732
# 85   ROC_sxntastico  21.836963
# 87     DN_wonderful  20.358406
# 89       ROC_rbN777  19.806510
# 93     PeRo_Nannnnn  17.662656
# 94      BST_SzylzEN  16.392541
# 95         VP_ibiza  14.111527
# 92       VP_Lukarux  13.950606
